# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from stable_baselines3 import DQN, A2C
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
# Note: drawdown_penalty_weight was 2 by default
experiment_id = f'EXPERIMENT_2_{int(time.time())}'
print(experiment_id)
# Out:
# EXPERIMENT_2_1678524127

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_returns_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
RETURN_COLS = ['RF_RETURN'] + [f'{ticker}_RETURN' for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS

# %%
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 20,
    episode_length = 180
)

# %%
model = DQN(
    'MlpPolicy',
    train_env,
    verbose = 1,
    tensorboard_log = log_dir,
    seed = 5,
    learning_rate = 0.0002,
    batch_size = 64,
    exploration_fraction = (149/2)
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in range(1,150):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.8    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7720     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8344     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 8156     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 8802     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22.8    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8552     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8257     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8302     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22.4    |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 8120     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 8244     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.9    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8244     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8413     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9360     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.2    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5347     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.8    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8961     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.7    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.8    |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8209     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -22      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 7549     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.7    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 7645     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.8    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7925     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.4    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8044     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.2    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8069     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.4    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8189     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8297     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.4    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8225     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.4    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8381     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21.3    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8529     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19440    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 7639     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6559     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 7035     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 7212     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6772     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 7186     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 7220     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 7452     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 7743     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 7813     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 7738     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7804     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7790     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7914     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29520    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5469     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 6189     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 6656     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 6884     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7394     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7615     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7848     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 34560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7605     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 35280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7806     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7770     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7709     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 37440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7567     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7515     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7590     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39600    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2306     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4716     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5831     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 6168     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 42480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6606     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6786     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 7161     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 7320     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 45360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 7609     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 7741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 7827     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 47520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 7810     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 7987     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 7947     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 49680    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 640      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 50400    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00841  |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 756      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 51120    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00674  |
# |    n_updates        | 279      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 786      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 51840    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00885  |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 800      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 52560    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00658  |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 805      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 53280    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0108   |
# |    n_updates        | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 813      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 54000    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00822  |
# |    n_updates        | 999      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 812      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 54720    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00642  |
# |    n_updates        | 1179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 822      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 55440    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.01     |
# |    n_updates        | 1359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 821      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 56160    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00901  |
# |    n_updates        | 1539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 822      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 56880    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00664  |
# |    n_updates        | 1719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 814      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 57600    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0083   |
# |    n_updates        | 1899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 819      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 58320    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00679  |
# |    n_updates        | 2079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 822      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 59040    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00608  |
# |    n_updates        | 2259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 825      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 59760    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0072   |
# |    n_updates        | 2439     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 808      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 60480    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00578  |
# |    n_updates        | 2619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 788      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 61200    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00582  |
# |    n_updates        | 2799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 804      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 61920    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00694  |
# |    n_updates        | 2979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 816      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 62640    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00615  |
# |    n_updates        | 3159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 820      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 63360    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00791  |
# |    n_updates        | 3339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 833      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 64080    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00574  |
# |    n_updates        | 3519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.3    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 836      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 64800    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00469  |
# |    n_updates        | 3699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -17.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 840      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 65520    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00711  |
# |    n_updates        | 3879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.4    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 841      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 66240    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00663  |
# |    n_updates        | 4059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 844      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 66960    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.009    |
# |    n_updates        | 4239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 826      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 67680    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00655  |
# |    n_updates        | 4419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 822      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 68400    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00696  |
# |    n_updates        | 4599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 823      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 69120    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00803  |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 827      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 69840    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0054   |
# |    n_updates        | 4959     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 851      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 70560    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00648  |
# |    n_updates        | 5139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 835      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 71280    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00638  |
# |    n_updates        | 5319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 824      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00725  |
# |    n_updates        | 5499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 839      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 72720    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00726  |
# |    n_updates        | 5679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 842      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 73440    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00477  |
# |    n_updates        | 5859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 834      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 74160    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00775  |
# |    n_updates        | 6039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 836      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 74880    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00819  |
# |    n_updates        | 6219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 825      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 75600    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00593  |
# |    n_updates        | 6399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 825      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 76320    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00661  |
# |    n_updates        | 6579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 822      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 77040    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0069   |
# |    n_updates        | 6759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 823      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 77760    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00671  |
# |    n_updates        | 6939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 828      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 78480    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00815  |
# |    n_updates        | 7119     |
# ----------------------------------
# ...
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 5996     |
# |    fps              | 789      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 1079280  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0079   |
# |    n_updates        | 257319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6000     |
# |    fps              | 788      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1080000  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00961  |
# |    n_updates        | 257499   |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6004     |
# |    fps              | 779      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1080720  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0138   |
# |    n_updates        | 257679   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6008     |
# |    fps              | 764      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1081440  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0484   |
# |    n_updates        | 257859   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6012     |
# |    fps              | 774      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1082160  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0102   |
# |    n_updates        | 258039   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6016     |
# |    fps              | 782      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1082880  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.01     |
# |    n_updates        | 258219   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6020     |
# |    fps              | 792      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1083600  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0127   |
# |    n_updates        | 258399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6024     |
# |    fps              | 787      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1084320  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00908  |
# |    n_updates        | 258579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6028     |
# |    fps              | 796      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1085040  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00979  |
# |    n_updates        | 258759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6032     |
# |    fps              | 799      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 1085760  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0104   |
# |    n_updates        | 258939   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6036     |
# |    fps              | 804      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1086480  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.114    |
# |    n_updates        | 259119   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6040     |
# |    fps              | 808      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1087200  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0624   |
# |    n_updates        | 259299   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -17.8    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6044     |
# |    fps              | 817      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 1087920  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0081   |
# |    n_updates        | 259479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -17.9    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6048     |
# |    fps              | 821      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 1088640  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0432   |
# |    n_updates        | 259659   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6052     |
# |    fps              | 827      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 1089360  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0505   |
# |    n_updates        | 259839   |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_2_1678524127_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18.3    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6056     |
# |    fps              | 831      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1090080  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0202   |
# |    n_updates        | 260019   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6060     |
# |    fps              | 798      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1090800  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0114   |
# |    n_updates        | 260199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6064     |
# |    fps              | 816      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1091520  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0098   |
# |    n_updates        | 260379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -17.7    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 6068     |
# |    fps              | 839      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1092240  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00815  |
# |    n_updates        | 260559   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pavan\Desktop\senior_project\experiments\experiment_2.ipynb Cell 8 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_2.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> TIMESTEPS = 10_000 # number of timesteps between saves
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_2.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> for i in range(1,150):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_2.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a>     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_2.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a>     model.save(f'{models_dir}/{TIMESTEPS*i}')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\dqn\dqn.py:258, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245 def learn(
#     246     self,
#     247     total_timesteps: int,
#    (...)
#     255     reset_num_timesteps: bool = True,
#     256 ) -> OffPolicyAlgorithm:
# --> 258     return super(DQN, self).learn(
#     259         total_timesteps=total_timesteps,
#     260         callback=callback,
#     261         log_interval=log_interval,
#     262         eval_env=eval_env,
#     263         eval_freq=eval_freq,
#     264         n_eval_episodes=n_eval_episodes,
#     265         tb_log_name=tb_log_name,
#     266         eval_log_path=eval_log_path,
#     267         reset_num_timesteps=reset_num_timesteps,
#     268     )
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:366, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     364         # Special case when the user passes `gradient_steps=0`
#     365         if gradient_steps > 0:
# --> 366             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     368 callback.on_training_end()
#     370 return self
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\dqn\dqn.py:207, in DQN.train(self, gradient_steps, batch_size)
#     205     # Clip gradient norm
#     206     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 207     self.policy.optimizer.step()
#     209 # Increase update counter
#     210 self._n_updates += gradient_steps
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\optim\optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\optim\optimizer.py:23, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      21 try:
#      22     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 23     ret = func(self, *args, **kwargs)
#      24 finally:
#      25     torch.set_grad_enabled(prev_grad)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\optim\adam.py:234, in Adam.step(self, closure, grad_scaler)
#     231                 raise RuntimeError('`requires_grad` is not supported for `step` in differentiable mode')
#     232             state_steps.append(state['step'])
# --> 234     adam(params_with_grad,
#     235          grads,
#     236          exp_avgs,
#     237          exp_avg_sqs,
#     238          max_exp_avg_sqs,
#     239          state_steps,
#     240          amsgrad=group['amsgrad'],
#     241          beta1=beta1,
#     242          beta2=beta2,
#     243          lr=group['lr'],
#     244          weight_decay=group['weight_decay'],
#     245          eps=group['eps'],
#     246          maximize=group['maximize'],
#     247          foreach=group['foreach'],
#     248          capturable=group['capturable'],
#     249          differentiable=group['differentiable'],
#     250          fused=group['fused'],
#     251          grad_scale=grad_scale,
#     252          found_inf=found_inf)
#     254 return loss
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\optim\adam.py:300, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     297 else:
#     298     func = _single_tensor_adam
# --> 300 func(params,
#     301      grads,
#     302      exp_avgs,
#     303      exp_avg_sqs,
#     304      max_exp_avg_sqs,
#     305      state_steps,
#     306      amsgrad=amsgrad,
#     307      beta1=beta1,
#     308      beta2=beta2,
#     309      lr=lr,
#     310      weight_decay=weight_decay,
#     311      eps=eps,
#     312      maximize=maximize,
#     313      capturable=capturable,
#     314      differentiable=differentiable,
#     315      grad_scale=grad_scale,
#     316      found_inf=found_inf)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\optim\adam.py:363, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     360     param = torch.view_as_real(param)
#     362 # Decay the first and second moment running average coefficient
# --> 363 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     364 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     366 if capturable or differentiable:
#
# KeyboardInterrupt:
