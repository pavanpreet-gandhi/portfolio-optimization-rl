# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import time
from stable_baselines3 import DQN, A2C
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
experiment_id = f'EXPERIMENT_6_{int(time.time())}'
print(experiment_id)
# Out:
# EXPERIMENT_6_1678606705

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_stationary_features_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
FEATURES = ['RETURN_12', 'RETURN_26', 'RETURN_60', 'STD_20']

RETURN_COLS = ['RISK_FREE'] + [ticker for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS + [f'{ticker}_{feature}' for ticker in TICKERS for feature in FEATURES]

# %%
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 10,
    episode_length = 180,
    drawdown_penalty_weight = 1,
    allocations_in_obs = True,
)

# %%
model = DQN(
    'MlpPolicy',
    train_env,
    verbose=1,
    tensorboard_log=log_dir,
    seed=5,
    learning_rate=0.0003,
    batch_size=64,
    exploration_fraction=1.3
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\buffers.py:220: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 8.35GB > 7.02GB
#   warnings.warn(

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in tqdm(range(1, 300)):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
#   0%|          | 0/299 [00:00<?, ?it/s]
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7874     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.28     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6894     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 3.74     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7467     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.62     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7134     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.03     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6661     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.63     |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6913     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.87     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7153     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.65     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7349     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.13     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7504     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.46     |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7644     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.63     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 7778     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.06     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 7893     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.98     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8005     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9360     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.97     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5337     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.08     |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8302     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.97     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8948     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.553    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8688     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.89     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 7395     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.88     |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 7487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.84     |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7761     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.65     |
# |    exploration_rate | 0.448    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 7881     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.45     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 7957     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.55     |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8024     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.67     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8081     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.62     |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8145     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.81     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8199     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.78     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8257     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19440    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.92     |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6533     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.86     |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8281     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.62     |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 8637     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.456    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 8734     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 8536     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 8165     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.31     |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 8207     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.45     |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 8357     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.36     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 8384     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.13     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 7916     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 7353     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 27360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.18     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7469     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.03     |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7532     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7612     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29520    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.83     |
# |    exploration_rate | 0.448    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 7071     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.59     |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 7472     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.57     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 7747     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.52     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7519     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.74     |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7177     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.72     |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7369     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.54     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7458     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 34560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.49     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7520     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 35280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.59     |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7550     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.52     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7601     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.57     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7703     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 37440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.41     |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7675     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7725     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.7      |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7799     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39600    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.88     |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5941     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.08     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5718     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 6704     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 7347     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 42480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.89     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 7674     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.03     |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 7857     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 8010     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.82     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 8170     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 45360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 8273     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 8297     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 8328     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 47520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 8337     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 48240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.31     |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 8396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.35     |
# |    exploration_rate | 0.274    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 8421     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 49680    |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.35     |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 171      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 50400    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00266  |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 255      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 51120    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000992 |
# |    n_updates        | 279      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.51     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 284      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 51840    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00131  |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.61     |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 298      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 52560    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00168  |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.46     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 308      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 53280    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000914 |
# |    n_updates        | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.41     |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 315      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 54000    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00108  |
# |    n_updates        | 999      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.7      |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 324      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 54720    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00103  |
# |    n_updates        | 1179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 324      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 55440    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000638 |
# |    n_updates        | 1359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.93     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 332      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 56160    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00127  |
# |    n_updates        | 1539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.86     |
# |    exploration_rate | 0.307    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 333      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 56880    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000964 |
# |    n_updates        | 1719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.77     |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 333      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 57600    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000778 |
# |    n_updates        | 1899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6        |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 328      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 58320    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000618 |
# |    n_updates        | 2079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.01     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 327      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 59040    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000386 |
# |    n_updates        | 2259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.86     |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 331      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 59760    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00116  |
# |    n_updates        | 2439     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.85     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 344      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 60480    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00165  |
# |    n_updates        | 2619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.91     |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 338      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 61200    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000412 |
# |    n_updates        | 2799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.73     |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 347      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 61920    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00113  |
# |    n_updates        | 2979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 353      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 62640    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000966 |
# |    n_updates        | 3159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.14     |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 359      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 63360    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000763 |
# |    n_updates        | 3339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 5.94     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 352      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 64080    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00104  |
# |    n_updates        | 3519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.03     |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 349      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 64800    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000707 |
# |    n_updates        | 3699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.07     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 350      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 65520    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000895 |
# |    n_updates        | 3879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.37     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 346      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 66240    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000673 |
# |    n_updates        | 4059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.58     |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 346      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 66960    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00166  |
# |    n_updates        | 4239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.27     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 349      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 67680    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000964 |
# |    n_updates        | 4419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 350      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 68400    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00112  |
# |    n_updates        | 4599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 349      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 69120    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00175  |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.28     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 350      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 69840    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00103  |
# |    n_updates        | 4959     |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.28     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 383      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 70560    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0012   |
# |    n_updates        | 5139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.56     |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 386      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 71280    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00113  |
# |    n_updates        | 5319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.6      |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 367      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0015   |
# |    n_updates        | 5499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.48     |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 358      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 72720    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000969 |
# |    n_updates        | 5679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.11     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 351      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 73440    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000637 |
# |    n_updates        | 5859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.18     |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 343      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 74160    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00111  |
# |    n_updates        | 6039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.15     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 339      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 74880    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00108  |
# |    n_updates        | 6219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.14     |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 335      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 75600    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000835 |
# |    n_updates        | 6399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.26     |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 330      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 76320    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00231  |
# |    n_updates        | 6579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.2      |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 330      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 77040    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000816 |
# |    n_updates        | 6759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.48     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 329      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 77760    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00113  |
# |    n_updates        | 6939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 331      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 78480    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00114  |
# ...
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0614   |
# |    n_updates        | 729459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16492    |
# |    fps              | 464      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 2968560  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.245    |
# |    n_updates        | 729639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 16496    |
# |    fps              | 467      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 2969280  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.195    |
# |    n_updates        | 729819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 16500    |
# |    fps              | 466      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 2970000  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0113   |
# |    n_updates        | 729999   |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 16504    |
# |    fps              | 493      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2970720  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0138   |
# |    n_updates        | 730179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16508    |
# |    fps              | 484      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2971440  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.205    |
# |    n_updates        | 730359   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16512    |
# |    fps              | 487      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2972160  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0161   |
# |    n_updates        | 730539   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16516    |
# |    fps              | 477      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2972880  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0986   |
# |    n_updates        | 730719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16520    |
# |    fps              | 480      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2973600  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0125   |
# |    n_updates        | 730899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16524    |
# |    fps              | 483      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2974320  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0151   |
# |    n_updates        | 731079   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16528    |
# |    fps              | 476      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2975040  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0146   |
# |    n_updates        | 731259   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16532    |
# |    fps              | 478      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 2975760  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00764  |
# |    n_updates        | 731439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16536    |
# |    fps              | 478      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 2976480  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0124   |
# |    n_updates        | 731619   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16540    |
# |    fps              | 482      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 2977200  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00826  |
# |    n_updates        | 731799   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16544    |
# |    fps              | 481      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 2977920  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00972  |
# |    n_updates        | 731979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16548    |
# |    fps              | 481      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 2978640  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0122   |
# |    n_updates        | 732159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 16552    |
# |    fps              | 479      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 2979360  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.182    |
# |    n_updates        | 732339   |
# ----------------------------------
# Logging to experiments/logs\EXPERIMENT_6_1678606705_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 16556    |
# |    fps              | 352      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2980080  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0205   |
# |    n_updates        | 732519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16560    |
# |    fps              | 419      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2980800  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0381   |
# |    n_updates        | 732699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16564    |
# |    fps              | 459      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2981520  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.259    |
# |    n_updates        | 732879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16568    |
# |    fps              | 451      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2982240  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.145    |
# |    n_updates        | 733059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16572    |
# |    fps              | 455      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2982960  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0137   |
# |    n_updates        | 733239   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16576    |
# |    fps              | 459      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2983680  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00876  |
# |    n_updates        | 733419   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 16580    |
# |    fps              | 466      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2984400  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0173   |
# |    n_updates        | 733599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16584    |
# |    fps              | 469      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2985120  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0156   |
# |    n_updates        | 733779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16588    |
# |    fps              | 466      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 2985840  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.232    |
# |    n_updates        | 733959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16592    |
# |    fps              | 466      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 2986560  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0115   |
# |    n_updates        | 734139   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16596    |
# |    fps              | 468      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 2987280  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.302    |
# |    n_updates        | 734319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16600    |
# |    fps              | 471      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 2988000  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.219    |
# |    n_updates        | 734499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 16604    |
# |    fps              | 471      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 2988720  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.176    |
# |    n_updates        | 734679   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 16608    |
# |    fps              | 470      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 2989440  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.012    |
# |    n_updates        | 734859   |
# ----------------------------------
