# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import time
from stable_baselines3 import DQN, A2C
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
experiment_id = f'EXPERIMENT_3_{int(time.time())}' # TODO
print(experiment_id)
# Out:
# EXPERIMENT_3_1678527353

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_returns_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
RETURN_COLS = ['RF_RETURN'] + [f'{ticker}_RETURN' for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS

# %%
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 20,
    episode_length = 180
)

# %%
# TODO
model = A2C(
    'MlpPolicy',
    train_env,
    verbose = 1,
    tensorboard_log = log_dir,
    seed = 5,
    learning_rate = 0.0005,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in tqdm(range(1, 300)):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
#   0%|          | 0/299 [00:00<?, ?it/s]
# Logging to experiments/logs\EXPERIMENT_3_1678527353_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.62     |
# | time/                 |          |
# |    fps                | 141      |
# |    iterations         | 100      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -47.2    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.14     |
# |    value_loss         | 0.00305  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.69     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 200      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.389   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.518    |
# |    value_loss         | 0.0352   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.92     |
# | time/                 |          |
# |    fps                | 216      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -10.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.195   |
# |    value_loss         | 0.00548  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.65     |
# | time/                 |          |
# |    fps                | 229      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.27    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.107   |
# |    value_loss         | 0.00193  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.75     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.236   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.832    |
# |    value_loss         | 0.0837   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.58     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 600      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.372    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.773    |
# |    value_loss         | 0.0751   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.45     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.05    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.288   |
# |    value_loss         | 0.0102   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.84     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -18.8    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.21    |
# |    value_loss         | 0.00611  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.01     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 900      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0834  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.42     |
# |    value_loss         | 0.278    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.04     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.266    |
# |    value_loss         | 0.00807  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.45     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.339   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.124   |
# |    value_loss         | 0.00546  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.03     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 1200     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.51    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.115   |
# |    value_loss         | 0.00767  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.11     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 1300     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.31    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.438   |
# |    value_loss         | 0.0261   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.22     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -52.9    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0857  |
# |    value_loss         | 0.00192  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.87     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.14    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.471   |
# |    value_loss         | 0.0253   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.62     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.559   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.197    |
# |    value_loss         | 0.00619  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.72     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.1     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.303   |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.74     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.16    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.423    |
# |    value_loss         | 0.0361   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.99     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1900     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.19    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.419    |
# |    value_loss         | 0.0236   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.97     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 2000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -8.54    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.361   |
# |    value_loss         | 0.0166   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_3_1678527353_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.77     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.16    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.294   |
# |    value_loss         | 0.0169   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.63     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.792    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.274   |
# |    value_loss         | 0.0082   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.73     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -12.1    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.132    |
# |    value_loss         | 0.00809  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.61     |
# | time/                 |          |
# |    fps                | 282      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.36    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0292  |
# |    value_loss         | 0.000811 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.64     |
# | time/                 |          |
# |    fps                | 285      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.491    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.272    |
# |    value_loss         | 0.00805  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.82     |
# | time/                 |          |
# |    fps                | 285      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0689  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.026   |
# |    value_loss         | 0.00254  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.95     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.407   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2699     |
# |    policy_loss        | 1.08     |
# |    value_loss         | 0.165    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.86     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.641   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.357    |
# |    value_loss         | 0.0233   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.91     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.613    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.4     |
# |    value_loss         | 0.0186   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.88     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.175    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.342   |
# |    value_loss         | 0.0132   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.83     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.285    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.154   |
# |    value_loss         | 0.00337  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.8      |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.025    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.41     |
# |    value_loss         | 0.271    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.96     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -532     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.338    |
# |    value_loss         | 0.0197   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.83     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 1400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -604     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.503   |
# |    value_loss         | 0.0296   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.69     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -53.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0685  |
# |    value_loss         | 0.000849 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.74     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.191    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.745    |
# |    value_loss         | 0.076    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.69     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.5      |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0725  |
# |    value_loss         | 0.000712 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.65     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.263    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.533    |
# |    value_loss         | 0.0338   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.79     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -280     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.131   |
# |    value_loss         | 0.00212  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.8      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.74    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.448   |
# |    value_loss         | 0.0238   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_3_1678527353_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.53     |
# | time/                 |          |
# |    fps                | 308      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.091   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4099     |
# |    policy_loss        | 1.13     |
# |    value_loss         | 0.171    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.64     |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -57.4    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.012    |
# |    value_loss         | 0.00718  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.52     |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.408    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0655   |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.75     |
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.28    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.441   |
# |    value_loss         | 0.0248   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.8      |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -6.71    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.25     |
# |    value_loss         | 0.0117   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -67.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.163   |
# |    value_loss         | 0.00403  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.5      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.115   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0555   |
# |    value_loss         | 0.00149  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.59     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.578    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0133  |
# |    value_loss         | 0.000556 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.51     |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.207   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.228   |
# |    value_loss         | 0.00735  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.44     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.646   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.163    |
# |    value_loss         | 0.00528  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.52     |
# | time/                 |          |
# |    fps                | 281      |
# |    iterations         | 1100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.075    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5099     |
# |    policy_loss        | 1        |
# |    value_loss         | 0.121    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.66     |
# | time/                 |          |
# |    fps                | 283      |
# |    iterations         | 1200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -15.3    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0767  |
# |    value_loss         | 0.00527  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.63     |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.105    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0276  |
# |    value_loss         | 0.000617 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.39     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 1400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.129    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5399     |
# |    policy_loss        | 1.01     |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.755   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.721    |
# |    value_loss         | 0.062    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.31     |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.568    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0987   |
# |    value_loss         | 0.00219  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.66     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.253   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.205   |
# |    value_loss         | 0.00668  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.72     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 1800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -4.3     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.577   |
# |    value_loss         | 0.0427   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.64     |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 1900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -7.49    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0896   |
# |    value_loss         | 0.00417  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.68     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 2000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.71    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.671   |
# |    value_loss         | 0.0619   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_3_1678527353_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.59     |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.69    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.182    |
# |    value_loss         | 0.00369  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.57     |
# | time/                 |          |
# |    fps                | 282      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -1.82    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.175    |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.56     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -3.6     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.375    |
# |    value_loss         | 0.0247   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.58     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.407    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.326    |
# |    value_loss         | 0.0155   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.383    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.362    |
# |    value_loss         | 0.0159   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.72     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.0692  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.185   |
# |    value_loss         | 0.00421  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.384    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.615   |
# |    value_loss         | 0.0468   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.95     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.618    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.537    |
# |    value_loss         | 0.0397   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.0899   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.18     |
# |    value_loss         | 0.00373  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.09     |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -135     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.206   |
# |    value_loss         | 0.00972  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.25     |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.405    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.118   |
# |    value_loss         | 0.00239  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.27     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.71     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.579    |
# |    value_loss         | 0.0392   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.38     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -31.2    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.362    |
# |    value_loss         | 0.0223   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.33     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -81.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.00141  |
# |    value_loss         | 0.000217 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.28     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.555   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.0495  |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.37     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.538    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0173  |
# ...
# |    policy_loss        | 0.000541 |
# |    value_loss         | 0.000156 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.48     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 1224000  |
# | train/                |          |
# |    entropy_loss       | -0.0404  |
# |    explained_variance | -2.36    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 244799   |
# |    policy_loss        | 0.000287 |
# |    value_loss         | 0.00296  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.5       |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1224500   |
# | train/                |           |
# |    entropy_loss       | -0.09     |
# |    explained_variance | -145      |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 244899    |
# |    policy_loss        | -0.000448 |
# |    value_loss         | 0.00134   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.52     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 1225000  |
# | train/                |          |
# |    entropy_loss       | -0.0577  |
# |    explained_variance | -14.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 244999   |
# |    policy_loss        | 6.36e-06 |
# |    value_loss         | 4.21e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.45      |
# | time/                 |           |
# |    fps                | 266       |
# |    iterations         | 1100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 1225500   |
# | train/                |           |
# |    entropy_loss       | -0.0411   |
# |    explained_variance | -14.6     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 245099    |
# |    policy_loss        | -0.000215 |
# |    value_loss         | 0.00127   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.48      |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 1226000   |
# | train/                |           |
# |    entropy_loss       | -0.0856   |
# |    explained_variance | -70.7     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 245199    |
# |    policy_loss        | -0.000229 |
# |    value_loss         | 0.000434  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.46     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 1226500  |
# | train/                |          |
# |    entropy_loss       | -0.0316  |
# |    explained_variance | 0.716    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245299   |
# |    policy_loss        | 0.000114 |
# |    value_loss         | 0.00052  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.46      |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 1400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 1227000   |
# | train/                |           |
# |    entropy_loss       | -0.0492   |
# |    explained_variance | -17.9     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 245399    |
# |    policy_loss        | -0.000195 |
# |    value_loss         | 0.00124   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.42     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 1227500  |
# | train/                |          |
# |    entropy_loss       | -0.391   |
# |    explained_variance | -5.77    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245499   |
# |    policy_loss        | -0.0359  |
# |    value_loss         | 0.00103  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.34     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 1228000  |
# | train/                |          |
# |    entropy_loss       | -0.0638  |
# |    explained_variance | -2.52    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245599   |
# |    policy_loss        | 0.000109 |
# |    value_loss         | 8.67e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.34     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 1228500  |
# | train/                |          |
# |    entropy_loss       | -0.026   |
# |    explained_variance | 0.119    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245699   |
# |    policy_loss        | 6.41e-05 |
# |    value_loss         | 0.000314 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.34      |
# | time/                 |           |
# |    fps                | 268       |
# |    iterations         | 1800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 1229000   |
# | train/                |           |
# |    entropy_loss       | -0.0476   |
# |    explained_variance | 0.389     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 245799    |
# |    policy_loss        | -1.57e-05 |
# |    value_loss         | 1.17e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.31     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 1229500  |
# | train/                |          |
# |    entropy_loss       | -0.192   |
# |    explained_variance | -8.87    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245899   |
# |    policy_loss        | 0.00146  |
# |    value_loss         | 0.000124 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.28     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 1230000  |
# | train/                |          |
# |    entropy_loss       | -0.0788  |
# |    explained_variance | 0.0333   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 245999   |
# |    policy_loss        | 0.000543 |
# |    value_loss         | 0.00101  |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_3_1678527353_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.45     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1230500  |
# | train/                |          |
# |    entropy_loss       | -0.0264  |
# |    explained_variance | 0.0807   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 246099   |
# |    policy_loss        | -0.00015 |
# |    value_loss         | 0.00266  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.47     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1231000  |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | -0.707   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 246199   |
# |    policy_loss        | 0.011    |
# |    value_loss         | 0.0575   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 2.41      |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1231500   |
# | train/                |           |
# |    entropy_loss       | -0.0565   |
# |    explained_variance | 0.471     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 246299    |
# |    policy_loss        | -6.19e-05 |
# |    value_loss         | 0.000342  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 2.39     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1232000  |
# | train/                |          |
# |    entropy_loss       | -0.0909  |
# |    explained_variance | -26.4    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 246399   |
# |    policy_loss        | 7.22e-05 |
# |    value_loss         | 0.000242 |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pavan\Desktop\senior_project\experiments\experiment_3_train.ipynb Cell 8 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_3_train.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> TIMESTEPS = 10_000 # number of timesteps between saves
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_3_train.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for i in tqdm(range(1, 300)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_3_train.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_3_train.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     model.save(f'{models_dir}/{TIMESTEPS*i}')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\a2c\a2c.py:191, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     178 def learn(
#     179     self,
#     180     total_timesteps: int,
#    (...)
#     188     reset_num_timesteps: bool = True,
#     189 ) -> "A2C":
# --> 191     return super(A2C, self).learn(
#     192         total_timesteps=total_timesteps,
#     193         callback=callback,
#     194         log_interval=log_interval,
#     195         eval_env=eval_env,
#     196         eval_freq=eval_freq,
#     197         n_eval_episodes=n_eval_episodes,
#     198         tb_log_name=tb_log_name,
#     199         eval_log_path=eval_log_path,
#     200         reset_num_timesteps=reset_num_timesteps,
#     201     )
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:270, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     267         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     268         self.logger.dump(step=self.num_timesteps)
# --> 270     self.train()
#     272 callback.on_training_end()
#     274 return self
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\a2c\a2c.py:164, in A2C.train(self)
#     161     loss.backward()
#     163     # Clip grad norm
# --> 164     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#     165     self.policy.optimizer.step()
#     167 explained_var = explained_variance(self.rollout_buffer.values.flatten(), self.rollout_buffer.returns.flatten())
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\utils\clip_grad.py:43, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite)
#      41     total_norm = norms[0] if len(norms) == 1 else torch.max(torch.stack(norms))
#      42 else:
# ---> 43     total_norm = torch.norm(torch.stack([torch.norm(g.detach(), norm_type).to(device) for g in grads]), norm_type)
#      44 if error_if_nonfinite and torch.logical_or(total_norm.isnan(), total_norm.isinf()):
#      45     raise RuntimeError(
#      46         f'The total norm of order {norm_type} for gradients from '
#      47         '`parameters` is non-finite, so it cannot be clipped. To disable '
#      48         'this error and scale the gradients by the non-finite norm anyway, '
#      49         'set `error_if_nonfinite=False`')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\utils\clip_grad.py:43, in <listcomp>(.0)
#      41     total_norm = norms[0] if len(norms) == 1 else torch.max(torch.stack(norms))
#      42 else:
# ---> 43     total_norm = torch.norm(torch.stack([torch.norm(g.detach(), norm_type).to(device) for g in grads]), norm_type)
#      44 if error_if_nonfinite and torch.logical_or(total_norm.isnan(), total_norm.isinf()):
#      45     raise RuntimeError(
#      46         f'The total norm of order {norm_type} for gradients from '
#      47         '`parameters` is non-finite, so it cannot be clipped. To disable '
#      48         'this error and scale the gradients by the non-finite norm anyway, '
#      49         'set `error_if_nonfinite=False`')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\functional.py:1485, in norm(input, p, dim, keepdim, out, dtype)
#    1483     if not isinstance(p, str):
#    1484         _dim = [i for i in range(ndim)]  # noqa: C416 TODO: rewrite as list(range(m))
# -> 1485         return _VF.norm(input, p, dim=_dim, keepdim=keepdim)  # type: ignore[attr-defined]
#    1487 # TODO: when https://github.com/pytorch/pytorch/issues/33782 is fixed
#    1488 # remove the overloads where dim is an int and replace with BraodcastingList1
#    1489 # and remove next four lines, replace _dim with dim
#    1490 if dim is not None:
#
# KeyboardInterrupt:
