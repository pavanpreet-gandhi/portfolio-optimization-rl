# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import time
from stable_baselines3 import DQN, A2C, PPO
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
experiment_id = f'EXPERIMENT_7_{int(time.time())}'
print(experiment_id)
# Out:
# EXPERIMENT_7_1678556411

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_stationary_features_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
FEATURES = ['RETURN_12', 'RETURN_26', 'RETURN_60', 'STD_20']

RETURN_COLS = ['RISK_FREE'] + [ticker for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS + [f'{ticker}_{feature}' for ticker in TICKERS for feature in FEATURES]

# %%
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 10,
    episode_length = 180,
    drawdown_penalty_weight = 1,
    allocations_in_obs = True,
)

# %%
model = PPO(
    'MlpPolicy',
    train_env,
    verbose=1,
    tensorboard_log=log_dir,
    seed=5,
    learning_rate=0.0003,
    ent_coef=0.3,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in tqdm(range(1, 300)):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
#   0%|          | 0/299 [00:00<?, ?it/s]
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 4.06     |
# | time/              |          |
# |    fps             | 280      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 5.75         |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076143444 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.00486      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.881       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0077      |
# |    value_loss           | 0.145        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.66        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008982383 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.759      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 0.469       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.75        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004410646 |
# |    clip_fraction        | 0.00874     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.818      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.65        |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009120118 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.687      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00953    |
# |    value_loss           | 0.41        |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 5.84     |
# | time/              |          |
# |    fps             | 455      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 12288    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.1         |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004212741 |
# |    clip_fraction        | 0.00776     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.783      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 0.487       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006989504 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.745      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.71        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006660825 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.74       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.09        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006733707 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.762      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.397       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 5.77     |
# | time/              |          |
# |    fps             | 444      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.75        |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006351162 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.782      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 0.399       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.05        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006372904 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.664      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.443       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.43        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007203502 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.0847      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.748      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.47        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007759719 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.703      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.557       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.89     |
# | time/              |          |
# |    fps             | 455      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.76         |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0069806986 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.708       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 0.579        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 7.2         |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007595165 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.803      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.471       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 7.09         |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0072414246 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.752       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 0.461        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 7.48        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006979948 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.682      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.634       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 7.34     |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 7.23        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007553214 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.468      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 0.788       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.81        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005726886 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.762      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 0.823       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.69         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0069250558 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.752       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 0.599        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.37        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007354484 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.548      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.812       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.72     |
# | time/              |          |
# |    fps             | 455      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 53248    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.53         |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0056830994 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.67        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 0.78         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.61        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005588023 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.674      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.542       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.47        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004647172 |
# |    clip_fraction        | 0.0108      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.455      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00838    |
# |    value_loss           | 0.931       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.34        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007358865 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.668      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.529       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.16     |
# | time/              |          |
# |    fps             | 451      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 63488    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.34         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0075041307 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.525       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 0.729        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.27         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0048775366 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.584       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00856     |
# |    value_loss           | 0.824        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.27         |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0058340007 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.673       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 0.572        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 180       |
# |    ep_rew_mean          | 6.52      |
# | time/                   |           |
# |    fps                  | 269       |
# |    iterations           | 5         |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0056423 |
# |    clip_fraction        | 0.0227    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.02     |
# |    explained_variance   | 0.522     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.588    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0126   |
# |    value_loss           | 0.625     |
# ---------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.76     |
# | time/              |          |
# |    fps             | 432      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 73728    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.48         |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0077426294 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.639       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.639        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.26        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005759173 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.65       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.595       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.77        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006031124 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.776      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.435       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.68        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004531089 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.433      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.89        |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.79     |
# | time/              |          |
# |    fps             | 439      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 83968    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.5          |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0044946284 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.663       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.465        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.41         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0074998755 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.621       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.015       |
# |    value_loss           | 0.505        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.34         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0041641276 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.474       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 0.804        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.08         |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 5            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0051310067 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.499        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 0.653        |
# ------------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.65     |
# | time/              |          |
# |    fps             | 448      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 94208    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.92         |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0061448924 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.697       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 0.64         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.3         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006805297 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.663      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.528       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.58         |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0056975335 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.658       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.498        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.39         |
# | time/                   |              |
# |    fps                  | 270          |
# |    iterations           | 5            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0058218488 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.381        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.669       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.648        |
# ------------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.39     |
# | time/              |          |
# |    fps             | 447      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 104448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.03        |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008314468 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.724      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.431       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6            |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0075551798 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.795       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0161      |
# |    value_loss           | 0.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 5.55         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0063870815 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.723       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00895     |
# |    value_loss           | 0.678        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 5.12        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.007089173 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.0176      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.764      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.386       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 5.35     |
# | time/              |          |
# |    fps             | 457      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 114688   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 5.54         |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0067701116 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.74        |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 0.409        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 5.42         |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0077849166 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.612       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 0.506        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 5.81         |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0065206764 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.638       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 0.508        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.14        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.006941844 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.561      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.602       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.44     |
# | time/              |          |
# |    fps             | 435      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124928   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    value_loss           | 0.378        |
# ------------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 7.56     |
# | time/              |          |
# |    fps             | 504      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 3022848  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 7.18         |
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3024896      |
# | train/                  |              |
# |    approx_kl            | 0.0075468197 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.826       |
# |    n_updates            | 14760        |
# |    policy_gradient_loss | -0.0207      |
# |    value_loss           | 0.346        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 7.06        |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 3026944     |
# | train/                  |             |
# |    approx_kl            | 0.007760374 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.845      |
# |    n_updates            | 14770       |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 0.309       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.73         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 3028992      |
# | train/                  |              |
# |    approx_kl            | 0.0068165604 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.824       |
# |    n_updates            | 14780        |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 0.371        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.91        |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3031040     |
# | train/                  |             |
# |    approx_kl            | 0.008475579 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.88       |
# |    n_updates            | 14790       |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 0.236       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 7.09     |
# | time/              |          |
# |    fps             | 499      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 3033088  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.65        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3035136     |
# | train/                  |             |
# |    approx_kl            | 0.005359168 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.825      |
# |    n_updates            | 14810       |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.346       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.6          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 3037184      |
# | train/                  |              |
# |    approx_kl            | 0.0056136297 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.863       |
# |    n_updates            | 14820        |
# |    policy_gradient_loss | -0.0172      |
# |    value_loss           | 0.273        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.71         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 3039232      |
# | train/                  |              |
# |    approx_kl            | 0.0073847836 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.89        |
# |    n_updates            | 14830        |
# |    policy_gradient_loss | -0.018       |
# |    value_loss           | 0.337        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.04        |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3041280     |
# | train/                  |             |
# |    approx_kl            | 0.007223838 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.856      |
# |    n_updates            | 14840       |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.403       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 5.98     |
# | time/              |          |
# |    fps             | 503      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 3043328  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.27         |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 3045376      |
# | train/                  |              |
# |    approx_kl            | 0.0073036677 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.875       |
# |    n_updates            | 14860        |
# |    policy_gradient_loss | -0.0196      |
# |    value_loss           | 0.286        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.31        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 3047424     |
# | train/                  |             |
# |    approx_kl            | 0.007902316 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.904      |
# |    n_updates            | 14870       |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.208       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6            |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 3049472      |
# | train/                  |              |
# |    approx_kl            | 0.0077349404 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.809       |
# |    n_updates            | 14880        |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 0.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 6.14        |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 5           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 3051520     |
# | train/                  |             |
# |    approx_kl            | 0.008025987 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.897      |
# |    n_updates            | 14890       |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.278       |
# -----------------------------------------
# Logging to experiments/logs\EXPERIMENT_7_1678556411_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 6.48     |
# | time/              |          |
# |    fps             | 528      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3053568  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.74         |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3055616      |
# | train/                  |              |
# |    approx_kl            | 0.0066861277 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.896       |
# |    n_updates            | 14910        |
# |    policy_gradient_loss | -0.0201      |
# |    value_loss           | 0.273        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 6.49         |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 3057664      |
# | train/                  |              |
# |    approx_kl            | 0.0076311524 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.529        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.834       |
# |    n_updates            | 14920        |
# |    policy_gradient_loss | -0.0206      |
# |    value_loss           | 0.341        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 7.05         |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 3059712      |
# | train/                  |              |
# |    approx_kl            | 0.0065751406 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.888       |
# |    n_updates            | 14930        |
# |    policy_gradient_loss | -0.0181      |
# |    value_loss           | 0.242        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 7.22        |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3061760     |
# | train/                  |             |
# |    approx_kl            | 0.006579362 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.866      |
# |    n_updates            | 14940       |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 0.228       |
# -----------------------------------------
