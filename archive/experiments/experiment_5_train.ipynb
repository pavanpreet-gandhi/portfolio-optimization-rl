# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import time
from stable_baselines3 import DQN, A2C
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
experiment_id = f'EXPERIMENT_5_{int(time.time())}'
print(experiment_id)
# Out:
# EXPERIMENT_5_1678550931

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_stationary_features_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
FEATURES = ['RETURN_12', 'RETURN_26', 'RETURN_60', 'STD_20']

RETURN_COLS = ['RISK_FREE'] + [ticker for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS + [f'{ticker}_{feature}' for ticker in TICKERS for feature in FEATURES]

# %%
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 10,
    episode_length = 180,
    drawdown_penalty_weight = 1,
    allocations_in_obs = True,
)

# %%
model = A2C(
    'MlpPolicy',
    train_env,
    verbose=1,
    tensorboard_log=log_dir,
    seed=5,
    learning_rate=0.0005,
    ent_coef=1.0,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in tqdm(range(1, 300)):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
#   0%|          | 0/299 [00:00<?, ?it/s]
# Logging to experiments/logs\EXPERIMENT_5_1678550931_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 10.2     |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 100      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.579    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.689    |
# |    value_loss         | 0.0548   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 8.57     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 200      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -34.8    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.44     |
# |    value_loss         | 0.0315   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.59     |
# | time/                 |          |
# |    fps                | 214      |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.03    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0468  |
# |    value_loss         | 0.00149  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.25     |
# | time/                 |          |
# |    fps                | 229      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -9.34    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.263   |
# |    value_loss         | 0.013    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.96     |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.147   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.37     |
# |    value_loss         | 0.256    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.06     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 600      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.593   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.634    |
# |    value_loss         | 0.0552   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.37     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.0448   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.288   |
# |    value_loss         | 0.0139   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.05     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.13    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.687   |
# |    value_loss         | 0.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.83     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 900      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.226    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.15     |
# |    value_loss         | 0.182    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.5      |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.58    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.02     |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.52     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.46    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.396   |
# |    value_loss         | 0.0331   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.12     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1200     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -24.8    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.247   |
# |    value_loss         | 0.00911  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.45     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -7.88    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -1.03    |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.36     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.47    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0294  |
# |    value_loss         | 0.00315  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.29     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.54    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0586   |
# |    value_loss         | 0.00193  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.24     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.65     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.2     |
# |    value_loss         | 0.0052   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.29     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.17    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.268    |
# |    value_loss         | 0.018    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.35     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.189    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.838   |
# |    value_loss         | 0.0862   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.61     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -48.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.635   |
# |    value_loss         | 0.0661   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.63     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.556    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.574   |
# |    value_loss         | 0.0366   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_5_1678550931_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.54     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -26.8    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.196   |
# |    value_loss         | 0.00791  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -8.12    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.042    |
# |    value_loss         | 0.00189  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.35     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.706    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.153    |
# |    value_loss         | 0.00373  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6        |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.526    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.368    |
# |    value_loss         | 0.017    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.08     |
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -82.2    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.324   |
# |    value_loss         | 0.0146   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.3      |
# | time/                 |          |
# |    fps                | 289      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.76    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2599     |
# |    policy_loss        | -1.17    |
# |    value_loss         | 0.172    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.33     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.187   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2699     |
# |    policy_loss        | 1.08     |
# |    value_loss         | 0.138    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.39     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -24.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.295    |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.28     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.603   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.218    |
# |    value_loss         | 0.00639  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.38     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.71    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.129   |
# |    value_loss         | 0.00619  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.28     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.35    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0763  |
# |    value_loss         | 0.00337  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.569   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.615    |
# |    value_loss         | 0.0475   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.23     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.03    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.424   |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.1      |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.52    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00241 |
# |    value_loss         | 0.00178  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.06     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.275   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.133    |
# |    value_loss         | 0.00457  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.05     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.51    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0237   |
# |    value_loss         | 0.00295  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.08     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -41.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.738   |
# |    value_loss         | 0.0757   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.08     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.222    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.233   |
# |    value_loss         | 0.00679  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.18     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.167   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.213    |
# |    value_loss         | 0.00711  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.28    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.283   |
# |    value_loss         | 0.0119   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_5_1678550931_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.13     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.236   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.755    |
# |    value_loss         | 0.0865   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.25     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -8.14    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.429    |
# |    value_loss         | 0.0391   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.2      |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.4     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.742    |
# |    value_loss         | 0.0603   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.42     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.195   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.709   |
# |    value_loss         | 0.0599   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.28     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.164   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.426   |
# |    value_loss         | 0.0281   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.37     |
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.31    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.514    |
# |    value_loss         | 0.0447   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.81    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.316   |
# |    value_loss         | 0.0148   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.49     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -11      |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4799     |
# |    policy_loss        | -1.37    |
# |    value_loss         | 0.229    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.38     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.764   |
# |    value_loss         | 0.0647   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.44     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.896    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.246   |
# |    value_loss         | 0.00738  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.42     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.547    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0887   |
# |    value_loss         | 0.00268  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.62     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -35.8    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.197   |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.55     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.32     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.298   |
# |    value_loss         | 0.0102   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.47     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.341    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5399     |
# |    policy_loss        | 1.16     |
# |    value_loss         | 0.173    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.32     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.46    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.112    |
# |    value_loss         | 0.00438  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.25     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -6.45    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.156    |
# |    value_loss         | 0.0045   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.29     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.321   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.191   |
# |    value_loss         | 0.00728  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.39     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -17.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.512   |
# |    value_loss         | 0.0391   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.35     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 1900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.61    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.594    |
# |    value_loss         | 0.0576   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.53     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.93    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.781    |
# |    value_loss         | 0.0782   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_5_1678550931_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.44     |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.65    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0758  |
# |    value_loss         | 0.00403  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.31    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.614   |
# |    value_loss         | 0.0488   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.19     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -6.08    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0564  |
# |    value_loss         | 0.00339  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.24     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -6.89    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.252    |
# |    value_loss         | 0.0202   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.47     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.0284   |
# |    value_loss         | 0.000221 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.58     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.292    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.222   |
# |    value_loss         | 0.00811  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.75     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.15    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.383   |
# |    value_loss         | 0.0355   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.75     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0806  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.676    |
# |    value_loss         | 0.0596   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 6.99     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.00569 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.00587  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.16     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -428     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.536    |
# |    value_loss         | 0.0407   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.33     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.26    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.015   |
# |    value_loss         | 0.00425  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.32     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.95    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.285    |
# |    value_loss         | 0.0119   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.33     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.849   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.353   |
# |    value_loss         | 0.0143   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.25     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.48    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.275    |
# |    value_loss         | 0.013    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.37     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.0872   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.0496   |
# |    value_loss         | 0.00174  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 7.45     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.256    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.137    |
# ...
# |    fps                | 270      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 1108500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -89      |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 221699   |
# |    policy_loss        | -0.00484 |
# |    value_loss         | 0.00063  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.83     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 1109000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.73    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 221799   |
# |    policy_loss        | -0.145   |
# |    value_loss         | 0.00455  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.77     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 1109500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.18    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 221899   |
# |    policy_loss        | 1        |
# |    value_loss         | 0.124    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.63     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 1110000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.88    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 221999   |
# |    policy_loss        | 0.752    |
# |    value_loss         | 0.0685   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_5_1678550931_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.85     |
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1110500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.6     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222099   |
# |    policy_loss        | -0.627   |
# |    value_loss         | 0.0656   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 5.71      |
# | time/                 |           |
# |    fps                | 283       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1111000   |
# | train/                |           |
# |    entropy_loss       | -3.04     |
# |    explained_variance | -1.05e+03 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 222199    |
# |    policy_loss        | -1.44     |
# |    value_loss         | 0.265     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.45     |
# | time/                 |          |
# |    fps                | 286      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1111500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.44    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222299   |
# |    policy_loss        | -1.01    |
# |    value_loss         | 0.117    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.58     |
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1112000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -10.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222399   |
# |    policy_loss        | 1.1      |
# |    value_loss         | 0.148    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 1112500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -94.1    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222499   |
# |    policy_loss        | -0.973   |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.62     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 1113000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -22.5    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222599   |
# |    policy_loss        | -0.148   |
# |    value_loss         | 0.00787  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.41     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 1113500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -8.75    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222699   |
# |    policy_loss        | 0.0601   |
# |    value_loss         | 0.0092   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 1114000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -52.1    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222799   |
# |    policy_loss        | 0.28     |
# |    value_loss         | 0.0132   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.16     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 900      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 1114500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.11    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222899   |
# |    policy_loss        | 0.468    |
# |    value_loss         | 0.0258   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.18     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 1115000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -4.17    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 222999   |
# |    policy_loss        | 0.0887   |
# |    value_loss         | 0.0014   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.01     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 1115500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.782    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 223099   |
# |    policy_loss        | -0.38    |
# |    value_loss         | 0.0165   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.01     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 1116000  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.833    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 223199   |
# |    policy_loss        | 0.449    |
# |    value_loss         | 0.0258   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 5.05     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 1116500  |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.437    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 223299   |
# |    policy_loss        | -0.377   |
# |    value_loss         | 0.0168   |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pavan\Desktop\senior_project\experiments\experiment_5_train.ipynb Cell 8 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_5_train.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> TIMESTEPS = 10_000 # number of timesteps between saves
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_5_train.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for i in tqdm(range(1, 300)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_5_train.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_5_train.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     model.save(f'{models_dir}/{TIMESTEPS*i}')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\a2c\a2c.py:191, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     178 def learn(
#     179     self,
#     180     total_timesteps: int,
#    (...)
#     188     reset_num_timesteps: bool = True,
#     189 ) -> "A2C":
# --> 191     return super(A2C, self).learn(
#     192         total_timesteps=total_timesteps,
#     193         callback=callback,
#     194         log_interval=log_interval,
#     195         eval_env=eval_env,
#     196         eval_freq=eval_freq,
#     197         n_eval_episodes=n_eval_episodes,
#     198         tb_log_name=tb_log_name,
#     199         eval_log_path=eval_log_path,
#     200         reset_num_timesteps=reset_num_timesteps,
#     201     )
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     246 callback.on_training_start(locals(), globals())
#     248 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\policies.py:594, in ActorCriticPolicy.forward(self, obs, deterministic)
#     592 distribution = self._get_action_dist_from_latent(latent_pi)
#     593 actions = distribution.get_actions(deterministic=deterministic)
# --> 594 log_prob = distribution.log_prob(actions)
#     595 return actions, values, log_prob
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\distributions.py:278, in CategoricalDistribution.log_prob(self, actions)
#     277 def log_prob(self, actions: th.Tensor) -> th.Tensor:
# --> 278     return self.distribution.log_prob(actions)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\distributions\categorical.py:123, in Categorical.log_prob(self, value)
#     121 def log_prob(self, value):
#     122     if self._validate_args:
# --> 123         self._validate_sample(value)
#     124     value = value.long().unsqueeze(-1)
#     125     value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\distributions\distribution.py:292, in Distribution._validate_sample(self, value)
#     290     return
#     291 assert support is not None
# --> 292 valid = support.check(value)
#     293 if not valid.all():
#     294     raise ValueError(
#     295         "Expected value argument "
#     296         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     299         f"but found invalid values:\n{value}"
#     300     )
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\distributions\constraints.py:257, in _IntegerInterval.check(self, value)
#     256 def check(self, value):
# --> 257     return (value % 1 == 0) & (self.lower_bound <= value) & (value <= self.upper_bound)
#
# KeyboardInterrupt:
