# %%
# This notebook runs from the projects root directory.
import os
PROJECT_ROOT_DIRECTORY = 'senior_project'
while os.path.basename(os.getcwd()) != PROJECT_ROOT_DIRECTORY:
    os.chdir(os.pardir)
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: c:\Users\pavan\Desktop\senior_project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from stable_baselines3 import DQN, A2C
from environments.discrete_env_v2 import PortfolioManagementEnv

# %%
experiment_id = f'EXPERIMENT_1_{int(time.time())}'
print(experiment_id)
# Out:
# EXPERIMENT_1_1678523209

# %%
models_dir = f'experiments/models/{experiment_id}'
log_dir = f'experiments/logs'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_df = pd.read_csv('data\dow_10_returns_train.csv', index_col=0, parse_dates=True)

TICKERS = ['AXP', 'AAPL', 'BA', 'GS', 'INTC', 'JNJ', 'KO', 'NKE', 'PG', 'DIS']
RETURN_COLS = ['RF_RETURN'] + [f'{ticker}_RETURN' for ticker in TICKERS]
FEATURE_COLS = RETURN_COLS

# %%
# Note: drawdown_penalty_weight was 2 by default
train_env = PortfolioManagementEnv(
    train_df, 
    RETURN_COLS, 
    FEATURE_COLS, 
    window_size = 20,
    episode_length = 180
)

# %%
model = A2C(
    'MlpPolicy',
    train_env,
    verbose = 1,
    tensorboard_log = log_dir,
    seed = 5,
    learning_rate = 0.0005,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10_000 # number of timesteps between saves
for i in range(1,150):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
    model.save(f'{models_dir}/{TIMESTEPS*i}')
# Out:
# Logging to experiments/logs\EXPERIMENT_1_1678523209_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -17.1    |
# | time/                 |          |
# |    fps                | 117      |
# |    iterations         | 100      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.132   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.986   |
# |    value_loss         | 0.124    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -14.1    |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 200      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.875    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.434   |
# |    value_loss         | 0.0205   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -18      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.7     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.2      |
# |    value_loss         | 0.0129   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19      |
# | time/                 |          |
# |    fps                | 211      |
# |    iterations         | 400      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.103    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.852    |
# |    value_loss         | 0.0891   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -17.5    |
# | time/                 |          |
# |    fps                | 226      |
# |    iterations         | 500      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.399   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | -1.45    |
# |    value_loss         | 0.291    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.6    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 600      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -50.2    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00239 |
# |    value_loss         | 0.00156  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 700      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.528    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.088    |
# |    value_loss         | 0.00128  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0547  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.17     |
# |    value_loss         | 0.164    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 900      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.134    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0779  |
# |    value_loss         | 0.00313  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0674  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -1.31    |
# |    value_loss         | 0.217    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19      |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 1100     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -2.06    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.587   |
# |    value_loss         | 0.0733   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.2    |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 1200     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -3.07    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.297   |
# |    value_loss         | 0.0124   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.7    |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 1300     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -1.71    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.21     |
# |    value_loss         | 0.186    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.6    |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 1400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.102   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | -2.06    |
# |    value_loss         | 0.553    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 1500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.307   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | -1.39    |
# |    value_loss         | 0.231    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.0146  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.341    |
# |    value_loss         | 0.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 1700     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.354    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.165    |
# |    value_loss         | 0.00692  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 1800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.115    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -1.07    |
# |    value_loss         | 0.149    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 1900     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -5.5     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.424   |
# |    value_loss         | 0.0227   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 2000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.507   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.92    |
# |    value_loss         | 0.0957   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_1_1678523209_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -37.9    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0898  |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.38    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.648    |
# |    value_loss         | 0.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.7    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.081   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2299     |
# |    policy_loss        | -3.13    |
# |    value_loss         | 1.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -0.635   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2399     |
# |    policy_loss        | -1.09    |
# |    value_loss         | 0.174    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.168    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.288   |
# |    value_loss         | 0.00992  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 600      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.37    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.746    |
# |    value_loss         | 0.0801   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 291      |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -1.44    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.549    |
# |    value_loss         | 0.0433   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -1.97    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.645   |
# |    value_loss         | 0.0516   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 281      |
# |    iterations         | 900      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.00537 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2899     |
# |    policy_loss        | -1.14    |
# |    value_loss         | 0.163    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.387   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.311    |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | -0.342   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.821    |
# |    value_loss         | 0.0795   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -247     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.211    |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.7    |
# | time/                 |          |
# |    fps                | 282      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.131   |
# |    value_loss         | 0.00195  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.5    |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 1400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -24.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.533   |
# |    value_loss         | 0.0284   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 282      |
# |    iterations         | 1500     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -0.255   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.676    |
# |    value_loss         | 0.0656   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1600     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -2.19    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3599     |
# |    policy_loss        | -1.14    |
# |    value_loss         | 0.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.0407   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3699     |
# |    policy_loss        | -1.13    |
# |    value_loss         | 0.149    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -1.83    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.426    |
# |    value_loss         | 0.0251   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.136   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.347    |
# |    value_loss         | 0.019    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 2000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -0.0152  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.115    |
# |    value_loss         | 0.0117   |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_1_1678523209_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.00732  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 298      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.423   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4199     |
# |    policy_loss        | -3.05    |
# |    value_loss         | 0.974    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | -0.829   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.553    |
# |    value_loss         | 0.0467   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.4    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -21.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.57     |
# |    value_loss         | 0.0898   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.6    |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.0903   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4499     |
# |    policy_loss        | -3.27    |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | -0.183   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4599     |
# |    policy_loss        | -1.42    |
# |    value_loss         | 0.225    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | -0.938   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.85    |
# |    value_loss         | 0.0757   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | -0.763   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.741    |
# |    value_loss         | 0.0797   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | -0.266   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.515    |
# |    value_loss         | 0.0434   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | -0.0111  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4999     |
# |    policy_loss        | -2.02    |
# |    value_loss         | 0.548    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | 0.223    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.186    |
# |    value_loss         | 0.00436  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.7    |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 1200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | -0.898   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.128    |
# |    value_loss         | 0.00212  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -2.95    |
# |    explained_variance | -0.345   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.735    |
# |    value_loss         | 0.0677   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.112    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5399     |
# |    policy_loss        | -3.78    |
# |    value_loss         | 2.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.608   |
# |    value_loss         | 0.0588   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0.157    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.265   |
# |    value_loss         | 0.0122   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1700     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -2.95    |
# |    explained_variance | -2.09    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.476    |
# |    value_loss         | 0.044    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.599    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.245    |
# |    value_loss         | 0.0105   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.385    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5899     |
# |    policy_loss        | -3.05    |
# |    value_loss         | 1.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 2000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | 0.087    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5999     |
# |    policy_loss        | -1.49    |
# |    value_loss         | 0.291    |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_1_1678523209_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.463    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.371    |
# |    value_loss         | 0.0205   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | -1.05    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.675    |
# |    value_loss         | 0.0627   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | -0.988   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6299     |
# |    policy_loss        | -1.98    |
# |    value_loss         | 0.665    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | -0.39    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6399     |
# |    policy_loss        | -1.84    |
# |    value_loss         | 0.552    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0.0675   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.563    |
# |    value_loss         | 0.0579   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -1.59    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.42     |
# |    value_loss         | 0.0348   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.571    |
# |    value_loss         | 0.0477   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.2    |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.36     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.742   |
# |    value_loss         | 0.101    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.2    |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.26     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6899     |
# |    policy_loss        | -1.06    |
# |    value_loss         | 0.169    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.6    |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -2.67    |
# |    explained_variance | -7.22    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.711    |
# |    value_loss         | 0.191    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.1    |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -2.69    |
# |    explained_variance | -0.0604  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.514    |
# |    value_loss         | 0.0397   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.5    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -2.6     |
# |    explained_variance | -0.0224  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7199     |
# |    policy_loss        | -3.09    |
# |    value_loss         | 1.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.3    |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -2.47    |
# |    explained_variance | -0.372   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7299     |
# |    policy_loss        | -1.07    |
# |    value_loss         | 0.481    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.4    |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -2.3     |
# |    explained_variance | -45.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.168    |
# |    value_loss         | 0.0102   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.5    |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.318    |
# |    value_loss         | 0.039    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -21.3    |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -2.08    |
# |    explained_variance | -0.151   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.427    |
# |    value_loss         | 0.0674   |
# ...
# |    total_timesteps    | 640000   |
# | train/                |          |
# |    entropy_loss       | -0.839   |
# |    explained_variance | -125     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 127999   |
# |    policy_loss        | 0.00568  |
# |    value_loss         | 9.04e-05 |
# ------------------------------------
# Logging to experiments/logs\EXPERIMENT_1_1678523209_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.962    |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 640500   |
# | train/                |          |
# |    entropy_loss       | -0.884   |
# |    explained_variance | -9.78    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128099   |
# |    policy_loss        | -0.00401 |
# |    value_loss         | 0.000142 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.955    |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 641000   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.39    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128199   |
# |    policy_loss        | -0.0131  |
# |    value_loss         | 0.000183 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.962    |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 641500   |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -0.11    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128299   |
# |    policy_loss        | 0.0309   |
# |    value_loss         | 0.00173  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.967    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 642000   |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -3.79    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128399   |
# |    policy_loss        | 0.0103   |
# |    value_loss         | 5.5e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.98     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 642500   |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -11.1    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128499   |
# |    policy_loss        | -0.013   |
# |    value_loss         | 0.000251 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.979    |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 600      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 643000   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.225    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128599   |
# |    policy_loss        | -0.00767 |
# |    value_loss         | 0.000181 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.987    |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 700      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 643500   |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -0.00623 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128699   |
# |    policy_loss        | 0.0233   |
# |    value_loss         | 0.000436 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.989    |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 800      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 644000   |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.206    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128799   |
# |    policy_loss        | 0.0116   |
# |    value_loss         | 0.000195 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 0.996     |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 900       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 644500    |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -11.7     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 128899    |
# |    policy_loss        | -0.000894 |
# |    value_loss         | 3.7e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.988    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 645000   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -9.86    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 128999   |
# |    policy_loss        | -0.0123  |
# |    value_loss         | 0.00032  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.986    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1100     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 645500   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.525    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 129099   |
# |    policy_loss        | -0.00672 |
# |    value_loss         | 6.01e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.99     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1200     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 646000   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0.0935   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 129199   |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 0.000466 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.981    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 646500   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.406    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 129299   |
# |    policy_loss        | 0.0183   |
# |    value_loss         | 0.000215 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 0.982    |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 647000   |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -2.9     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 129399   |
# |    policy_loss        | -0.0106  |
# |    value_loss         | 0.000116 |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pavan\Desktop\senior_project\experiments\experiment_1_train.ipynb Cell 8 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_1_train.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> TIMESTEPS = 10_000 # number of timesteps between saves
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_1_train.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for i in range(1,150):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_1_train.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=experiment_id)
#       <a href='vscode-notebook-cell:/c%3A/Users/pavan/Desktop/senior_project/experiments/experiment_1_train.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     model.save(f'{models_dir}/{TIMESTEPS*i}')
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\a2c\a2c.py:191, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     178 def learn(
#     179     self,
#     180     total_timesteps: int,
#    (...)
#     188     reset_num_timesteps: bool = True,
#     189 ) -> "A2C":
# --> 191     return super(A2C, self).learn(
#     192         total_timesteps=total_timesteps,
#     193         callback=callback,
#     194         log_interval=log_interval,
#     195         eval_env=eval_env,
#     196         eval_freq=eval_freq,
#     197         n_eval_episodes=n_eval_episodes,
#     198         tb_log_name=tb_log_name,
#     199         eval_log_path=eval_log_path,
#     200         reset_num_timesteps=reset_num_timesteps,
#     201     )
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     246 callback.on_training_start(locals(), globals())
#     248 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\policies.py:589, in ActorCriticPolicy.forward(self, obs, deterministic)
#     587 # Preprocess the observation if needed
#     588 features = self.extract_features(obs)
# --> 589 latent_pi, latent_vf = self.mlp_extractor(features)
#     590 # Evaluate the values for the given observations
#     591 values = self.value_net(latent_vf)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\torch_layers.py:230, in MlpExtractor.forward(self, features)
#     225 """
#     226 :return: latent_policy, latent_value of the specified network.
#     227     If all layers are shared, then ``latent_policy == latent_value``
#     228 """
#     229 shared_latent = self.shared_net(features)
# --> 230 return self.policy_net(shared_latent), self.value_net(shared_latent)
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\pavan\anaconda3\envs\rl_env\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
